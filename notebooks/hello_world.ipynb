# %%
# %pylab
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

plt.xkcd()

#def func(x): return x * x
func = lambda x : x * x / (2 - x * x + x)
x = np.linspace(0, 10, 100)
y = func(x)
plt.plot(x, y)
plt.plot(x, 0.1 * y)
plt.ylabel('test')
plt.xlabel('time, seconds')
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
# %reset -f
import ROOT
from ResonanceDecay import GetPseudoRandomData

c = ROOT.TCanvas("some","The Canvas Title",800,600)
phi = GetPseudoRandomData()
phi.Draw()


# old-but way to display root-image
c.SaveAs('deleteme.png')
from IPython.display import Image
Image(filename='deleteme.png') 


ROOT.enableJSVis()
c.Draw()
